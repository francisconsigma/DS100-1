# %%
#importing the required Phyton libraries

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Define the URL
url = "https://raw.githubusercontent.com/francisconsigma/DS100-1/main/public-health-expenditure-share-GDP-OWID.csv"

# Read the CSV file from the URL
df = pd.read_csv(url)

# Display the DataFrame
df
# Out:
#              Entity Code  Year  public_health_expenditure_pc_gdp
# 0           Albania  ALB  2010                             2.442
# 1           Albania  ALB  2011                             2.387
# 2           Albania  ALB  2012                             2.474
# 3           Albania  ALB  2013                             2.605
# 4           Albania  ALB  2014                             2.617
# ...             ...  ...   ...                               ...
# 2172  United States  USA  2016                            13.912
# 2173  United States  USA  2017                            13.890
# 2174  United States  USA  2018                            13.796
# 2175  United States  USA  2019                            13.813
# 2176  United States  USA  2020                            15.949
#
# [2177 rows x 4 columns]

# %%
# Convert the 'Year' column to datetime
data['Year'] = pd.to_datetime(data['Year'], format='%Y')

# Plotting the line graph
fig, ax = plt.subplots(figsize=(10, 6))
for code in data['Code'].unique():
    subset = data[data['Code'] == code]
    ax.plot(subset['Year'], subset['public_health_expenditure_pc_gdp'], label=code)

plt.xlabel('Year')
plt.ylabel('Public Health Expenditure Share of GDP')
plt.title('Public Health Expenditure Share of GDP by Country over Time')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.grid(True)
plt.subplots_adjust(right=0.8)  # Adjust the right margin
plt.show()

# %%
# Convert the 'Year' column to datetime
data['Year'] = pd.to_datetime(data['Year'], format='%Y')

# Get unique codes and their corresponding colors
codes = data['Code'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(codes)))

# Set up the interactive scatter plot
fig, ax = plt.subplots(figsize=(10, 6))
for i, code in enumerate(codes):
    subset = data[data['Code'] == code]
    ax.scatter(subset['Year'], subset['public_health_expenditure_pc_gdp'], c=[colors[i]], label=code, alpha=0.7)

# Set the x-axis and y-axis labels
ax.set_xlabel('Year')
ax.set_ylabel('Public Health Expenditure Share of GDP')

# Set the title
ax.set_title('Public Health Expenditure Share of GDP by Country')

# Move the legend to the right side
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the URL
url = "https://raw.githubusercontent.com/francisconsigma/DS100-1/main/public-health-expenditure-share-GDP-OWID.csv"

# Read the CSV file from the URL
data = pd.read_csv(url)

# Filter the data for the desired columns
filtered_data = data[['Code', 'Year', 'public_health_expenditure_pc_gdp']]

# Sort the data by the public_health_expenditure_pc_gdp column in descending order
sorted_data = filtered_data.sort_values(by='public_health_expenditure_pc_gdp', ascending=False)

# Define custom color palette
colors = ['steelblue', 'forestgreen', 'orange', 'purple', 'salmon']

# Plotting the horizontal bar graph
plt.figure(figsize=(12, 8))
bars = plt.barh(sorted_data['Year'], sorted_data['public_health_expenditure_pc_gdp'], color=colors)
plt.xlabel('Public Health Expenditure per Capita (% of GDP)')
plt.ylabel('Year')
plt.title('Public Health Expenditure per Capita (% of GDP) by Year')
plt.grid(True)

# Create a legend with the 'Code' values
legend_labels = sorted_data['Code'].unique()
plt.legend(bars, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust the margins

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv('public-health-expenditure-share-GDP-OWID.csv')

# Select the required columns
data = data[['Code', 'Year', 'public_health_expenditure_pc_gdp']]

# Pivot the data to have years as columns
data_pivot = data.pivot(index='Code', columns='Year', values='public_health_expenditure_pc_gdp')

# Sort the data by country code
data_pivot.sort_index(inplace=True)

# Plot the stairs plot
fig, ax = plt.subplots(figsize=(10, 6))
for i, country in enumerate(data_pivot.index):
    y = data_pivot.loc[country].dropna()
    x = y.index.astype(int)
    plt.step(x, y, label=country)

plt.xlabel('Year')
plt.ylabel('Public Health Expenditure (% of GDP)')
plt.title('Public Health Expenditure Over Time')

# Adjust the legend position
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))

plt.xticks(rotation=45)

# Adjust the figure layout manually
plt.subplots_adjust(right=0.8)

plt.show()

# %%
# Convert the 'Year' column to datetime
data['Year'] = pd.to_datetime(data['Year'], format='%Y')

# Set up the interactive line graph using Plotly Express
fig = px.line(
    data,
    x='Year',
    y='public_health_expenditure_pc_gdp',
    color='Code',
    hover_data=['Code']
)

# Set the x-axis and y-axis labels
fig.update_xaxes(title_text='Year')
fig.update_yaxes(title_text='Public Health Expenditure Share of GDP')

# Set the title
fig.update_layout(title_text='Public Health Expenditure Share of GDP by Country')

# Show the interactive line graph
fig.show()

# %%
# Convert the 'Year' column to datetime
data['Year'] = pd.to_datetime(data['Year'], format='%Y')

# Set up the interactive scatter plot using Plotly Express
fig = px.scatter(data, x='Year', y='public_health_expenditure_pc_gdp', color='Code', hover_data=['Code'])

# Set the x-axis and y-axis labels
fig.update_xaxes(title_text='Year')
fig.update_yaxes(title_text='Public Health Expenditure Share of GDP')

# Set the title
fig.update_layout(title_text='Public Health Expenditure Share of GDP by Country')

# Show the interactive scatter plot
fig.show()

# %%
# Filter the data for the desired columns
filtered_data = data[['Code', 'Year', 'public_health_expenditure_pc_gdp']]

# Sort the data by the public_health_expenditure_pc_gdp column in descending order
sorted_data = filtered_data.sort_values(by='public_health_expenditure_pc_gdp', ascending=False)

# Create an interactive bar graph using plotly
fig = px.bar(sorted_data, y='Year', x='public_health_expenditure_pc_gdp', text='public_health_expenditure_pc_gdp',
             color='public_health_expenditure_pc_gdp', orientation='h', height=600, hover_name='Code',
             labels={'public_health_expenditure_pc_gdp': 'Public Health Expenditure per Capita (% of GDP)'})

# Customize the layout
fig.update_layout(title='Public Health Expenditure per Capita (% of GDP) by Year',
                  xaxis_title='Public Health Expenditure per Capita (% of GDP)',
                  yaxis_title='Year',
                  xaxis_tickformat='.1%',
                  uniformtext_minsize=8, uniformtext_mode='hide',
                  hovermode='closest')

# Display the interactive graph
fig.show()

# %%
# Select the required columns
data = data[['Code', 'Year', 'public_health_expenditure_pc_gdp']]

# Pivot the data to have years as columns
data_pivot = data.pivot(index='Code', columns='Year', values='public_health_expenditure_pc_gdp')

# Reset the index
data_pivot = data_pivot.reset_index()

# Melt the data to long format
data_melted = pd.melt(data_pivot, id_vars='Code', var_name='Year', value_name='Public Health Expenditure (% of GDP)')

# Create the stairs plot using plotly.express
fig = px.line(data_melted, x='Year', y='Public Health Expenditure (% of GDP)', color='Code', line_shape='hv')

# Set the title and axis labels
fig.update_layout(
    title='Public Health Expenditure Over Time',
    xaxis_title='Year',
    yaxis_title='Public Health Expenditure (% of GDP)'
)

# Show the figure
fig.show()

# %% [markdown]
# Consigma, Francis Ivan D.
# 2021103872
#
# The student has imported the required Python libraries for data analysis and visualization, including Pandas, NumPy, Matplotlib, and Plotly Express. He had loaded a CSV file containing data on public health expenditure share of GDP by country over time. The student has created multiple visualizations to explore and analyze the data. he started with a line graph using Matplotlib, where each country is represented by a separate line. The x-axis represents the years, and the y-axis represents the public health expenditure share of GDP. By observing the lines, we can identify the trends and changes in public health expenditure over time for each country. Next, the student created an interactive scatter plot using Matplotlib. Each data point represents a specific year and the corresponding public health expenditure share of GDP for a particular country. The scatter plot allows us to see the distribution and patterns of public health expenditure among countries. By hovering over the data points, the student has added interactivity to display the country code, providing more information when needed. Then, the student used Plotly Express to create an interactive line graph. The graph represents the same information as the initial line graph, but with the added interactivity provided by Plotly Express. By hovering over the lines, the country code and public health expenditure share of GDP for a specific year are displayed. This allows for a more detailed exploration of the data and facilitates comparison between countries. Finally, the student created an interactive scatter plot using Plotly Express. Similar to the scatter plot created with Matplotlib, this plot allows for exploration of the distribution and patterns of public health expenditure share of GDP among countries. The interactivity provided by Plotly Express enhances the visualization by providing additional details on the country codes. Regarding the observed trends in the visualizations, it would require actually running the code and analyzing the data to provide specific insights. However, some general observations that could be made include identifying countries with consistently high or low public health expenditure share of GDP over time, identifying periods of significant changes in expenditure, and comparing the trends between different countries. Overall, the student has effectively utilized Python libraries to visualize and explore the data on public health expenditure share of GDP. The combination of line graphs, scatter plots, and interactivity through Plotly Express provides multiple perspectives for analyzing the data and uncovering trends and patterns in public health expenditure across countries over time.The data was first loaded into a pandas DataFrame using the pd.read_csv() function. The relevant columns for analysis were selected, including 'Code', 'Year', and 'public_health_expenditure_pc_gdp'. The DataFrame was then sorted in descending order based on the 'public_health_expenditure_pc_gdp' column. To visualize the data, a horizontal bar graph was generated using the matplotlib library. The 'Year' column was plotted on the y-axis, while the 'public_health_expenditure_pc_gdp' column represented the x-axis. Each bar in the graph represented the public health expenditure per capita as a percentage of GDP for a specific year. The graph provided an overview of how this expenditure varied across different years. To enhance the interactivity and visualization capabilities, an interactive bar graph was created using the plotly library. The sorted data was used to generate the graph, which offered additional features such as hover information. The 'Year' column was plotted on the y-axis, and the 'public_health_expenditure_pc_gdp' column was represented on the x-axis. Each bar in the graph represented the public health expenditure per capita as a percentage of GDP for a specific year. By hovering over the bars, users could view additional information such as the country code ('Code').
